# %%
print('Hello World!')
# Out:
# Hello World!

# %%
print(2+3)
# Out:
# 5

# %%
print('Strait '+'Of '+'Hormouz😭')
# Out:
# Strait Of Hormouz😭

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# # First NoteBook File

# %%
print('Hello Data Analysis, This Side Vivek The Analyst')
# Out:
# Hello Data Analysis, This Side Vivek The Analyst

# %%
a = "Love"
print("".join(reversed(a)))
# Out:
# evoL

# %%
result_a = a[::-1]
print(result_a)
# Out:
# evoL

# %%
print('Indian Premier League')
# Out:
# Indian Premier League
