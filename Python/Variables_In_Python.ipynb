# %% [markdown]
# # Variables In Python

# %%
x = 25
print(x)
# Out:
# 25

# %%
 print(type(x))
# Out:
# <class 'int'>

# %%
type(x)
# Out:
# int

# %%
y = 'Mint Chocklate Chip Mocca'
print(y)
# Out:
# Mint Chocklate Chip Mocca

# %%
print(type(y))
# Out:
# <class 'str'>

# %%
type(y)
# Out:
# str

# %%
y = 'Mango Shake' #if only used this then that would have given us the mango shake as we here assinged the with it
y = "Strawberry latte " #here this will get print because wehave reassinged the vale of y
print(y)
# Out:
# Strawberry latte

# %%
x,y,z = "Bournvita","Horlicks","Boosts"#Here assinging multiple values to each variable
print(x)
print(y)
print(z)
# Out:
# Bournvita
# Horlicks
# Boosts

# %%
print(x+y+z)
# Out:
# BournvitaHorlicksBoosts

# %%
x=y=z = "Bellavita" #Here we are assiging same value to all three variable
print(x,y,z)
# Out:
# Bellavita Bellavita Bellavita

# %% [markdown]
# # List Creation

# %%
shakes_list = ["Bournvita","Horlicks","Boosts"]
print(shakes_list[0])
# Out:
# Bournvita

# %%
print(" ".join(reversed(shakes_list)))
# Out:
# Boosts Horlicks Bournvita

# %%
x,y,z = shakes_list # Each variable will get the value from the list automatically
print(x)
print(y)
print(z)
# Out:
# Bournvita
# Horlicks
# Boosts

# %% [markdown]
# # Ways of writing a variable in python

# %%
#Ways of writing a variable in python
# Camel Case - 1st is small rest can be capital
testVariableCase = "Watermelon Shake" 
# Pascal Case - 1st cis capital and rest can also remain big
TestVariableCase = "Banana Shake" 
# Snake Case - No captial letter and seperate each with an underscore
test_variable_case = "Guava Shake"

# %%
# These are the correct way to assing a variable
testvar = "Raju"
test_var = "Bheem"
_test_var = "Jaggu"
testVar = "Kaliya"
TestVar = "Dholu"
testVar2 = "Bholu"

# %%
# Ways not to declare a variable - It gives the invalid syntax error
test-var = "Chutki"
2testVar = "Indumati"
test Var2 = "Tuntun"

# %%
x_ = "HariOmHari" # Here we have given the single letter with the underscore
for i in x_:
    print(i)
# Out:
# H
# a
# r
# i
# O
# m
# H
# a
# r
# i

# %% [markdown]
# # Some Explorations

# %%
x = "Soya Chaap & Chole Bhature "
y = "Are "
z = "My Favourite Food Items"
a = " ."
print(x+y+z+a)# Concatenation Of Strings
# Out:
# Soya Chaap & Chole Bhature Are My Favourite Food Items .

# %%
# How to take input in python
a = int(input("Enter 1st number: "))
b = int(input("Enter 2nd number: "))
z = a+b
print("Your exponent root is: ",a**b)
print("Your addition is: ",z)
print("Your subtraction is: ",a-b)
print("Your multiplication is : ",a*b)
print("Your division is :",abs(a/b))
# Out:
# Enter 1st number:  5
# Enter 2nd number:  3
# Your exponent root is:  125
# Your addition is:  8
# Your subtraction is:  2
# Your multiplication is :  15
# Your division is : 1.6666666666666667

# %%
a = 'Ice Cream'
b = 2
print(a,"-",b)
# Out:
# Ice Cream - 2
